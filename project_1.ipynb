# %% [markdown]
# # I used 2012 SAT result in NYC public schools as dataset in project 1

# %%
import pandas as pd

df = pd.read_csv("2012_SAT_Results_20251105.csv")
df.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# 2                    370
# 3                    359
# 4                    384

# %% [markdown]
# #Data cleaning

# %%
import re
clean = df[numeric_col].astype(str).str.replace(r"[^0-9\.-]", "", regex=True)
df[numeric_col] = pd.to_numeric(clean, errors="coerce")

# %% [markdown]
# #Calculate mean, median, and mode for SAT Math score (pandas version)

# %%
numeric_col = 'SAT Math Avg. Score'  # Replace with an actual column name from your CSV
mean_value = df[numeric_col].mean()
median_value = df[numeric_col].median()
mode_value = df[numeric_col].mode()[0]

print(f"Mean: {mean_value:.2f}")
print(f"Median: {median_value:.2f}")
print(f"Mode: {mode_value:.2f}")
# Out:
# Mean: 413.37
# Median: 395.00
# Mode: 385.00

# %%
# Calculate mean, median, and mode without using pandas built-in functions

# Mean
mean_value_hard = sum(values) / len(values)

# Median
sorted_values = sorted(values)
mid = len(sorted_values) // 2
if len(sorted_values) % 2 == 0:
    median_value_hard = (sorted_values[mid - 1] + sorted_values[mid]) / 2
else:
    median_value_hard = sorted_values[mid]

# Mode
freq = {}
for v in values:
    freq[v] = freq.get(v, 0) + 1
mode_value_hard = max(freq, key=freq.get)

print(f"Hard Way - Mean: {mean_value_hard:.2f}")
print(f"Hard Way - Median: {median_value_hard:.2f}")
print(f"Hard Way - Mode: {mode_value_hard:.2f}")
# Out:
# Hard Way - Mean: 413.37
# Hard Way - Median: 395.00
# Hard Way - Mode: 385.00

# %% [markdown]
# #Data Visualization

# %%
# Obtain frequency counts (from earlier)
for value, count in sorted(freq.items()):
    stars = '*' * int(count / max(freq.values()) * 50)  # Scale for visual clarity
    print(f"{value}: {stars}")
# Out:
# 312.0: *****
# 315.0: *****
# 317.0: *****
# 318.0: *****
# 320.0: *****
# 322.0: *****
# 323.0: ***********
# 324.0: *****
# 333.0: *****
# 335.0: ***********
# 337.0: *****
# 338.0: *****
# 339.0: *****
# 341.0: *****
# 342.0: *****
# 344.0: *****
# 346.0: ***********
# 349.0: *********************************
# 350.0: *****
# 351.0: ***********
# 353.0: **********************
# 355.0: ****************
# 356.0: ***************************
# 357.0: *********************************
# 358.0: ****************
# 359.0: ***********
# 360.0: ****************
# 361.0: **********************
# 362.0: ****************
# 363.0: ***********
# 364.0: ********************************************
# 365.0: ***************************
# 366.0: ***********
# 367.0: **********************
# 368.0: **********************
# 369.0: ***************************
# 370.0: *********************************
# 371.0: ********************************************
# 372.0: ***************************
# ...
